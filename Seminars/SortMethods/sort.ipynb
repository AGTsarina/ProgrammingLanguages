# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('res.csv', sep=';')
df
# Out:
#         N  sotr_exchange  sotr_select  sort_insert  heap_sort  quick_sort  \
# 0    1000       0.015967     0.005546     0.005880   0.000563    0.000316
# 1    2000       0.039416     0.008061     0.010637   0.000570    0.000318
# 2    3000       0.062101     0.018182     0.023074   0.000944    0.000481
# 3    4000       0.112283     0.031215     0.041524   0.001241    0.000661
# 4    5000       0.173702     0.052398     0.062721   0.001647    0.000854
# 5    6000       0.253430     0.080447     0.108722   0.001945    0.001055
# 6    7000       0.364431     0.102438     0.137209   0.002563    0.001362
# 7    8000       0.476602     0.135486     0.174413   0.002782    0.001438
# 8    9000       0.595828     0.163870     0.244512   0.003671    0.001841
# 9   10000       0.720977     0.203627     0.266454   0.003591    0.001752
# 10  11000       0.894430     0.255869     0.329976   0.003852    0.002042
# 11  12000       1.060730     0.300545     0.401866   0.004748    0.002378
# ...

# %%
df['N']
# Out:
# 0      1000
# 1      2000
# 2      3000
# 3      4000
# 4      5000
# 5      6000
# 6      7000
# 7      8000
# 8      9000
# 9     10000
# 10    11000
# 11    12000
# 12    13000
# 13    14000
# 14    15000
# 15    16000
# 16    17000
# 17    18000
# 18    19000
# Name: N, dtype: int64

# %%
ax = plt.subplot()
ax.plot(df['N'], df['sotr_exchange'], 'r-')
ax.plot(df['N'], df['sotr_select'], 'r-')
ax.plot(df['N'], df['sort_insert'], 'r-')
ax.plot(df['N'], df['heap_sort'], 'b-')
ax.plot(df['N'], df['quick_sort'], 'b-')

# %%
ax = plt.subplot()
ax.plot(df['N'], df['sotr_exchange'], 'r-')
ax.plot(df['N'], df['sotr_select'], 'b-')
ax.plot(df['N'], df['sort_insert'], 'g-')

# %%
import numpy as np
ax = plt.subplot()
x = np.array(df['N'])
y = x * np.log2(x) / 38371770.9809616
ax.plot(df['N'], df['heap_sort'], 'r-')
ax.plot(df['N'], df['quick_sort'], 'b-')
ax.plot(x, y, 'g--')

# %%
x
# Out:
# array([ 1000,  2000,  3000,  4000,  5000,  6000,  7000,  8000,  9000,
#        10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000,
#        19000])

# %%
y
# Out:
# array([  9965.78428466,  21931.56856932,  34652.24035615,  47863.13713865,
#         61438.56189775,  75304.4807123 ,  89411.97444704, 103726.2742773 ,
#        118221.38357494, 132877.12379549, 147677.37493629, 162608.9614246 ,
#        177660.91203644, 192823.94889408, 208090.12320406, 223452.54855459,
#        238905.20114051, 254442.76714988, 270060.52416401])

# %%
k = y.max() / 0.007038
k
# Out:
# np.float64(38371770.9809616)
